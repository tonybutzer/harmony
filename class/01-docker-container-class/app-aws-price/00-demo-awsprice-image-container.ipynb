# %%
! cat Makefile
# Out:
# Image=tbutzer/aws-price
#
# build:
# 	docker build -t ${Image} .
#
# run:
# 	docker run -it ${Image} bash
#
# exec:
# 	docker exec -it ${Image} bash
#
# dockerhub_publish:
# 	(docker login && docker push ${Image})

# %%
! cat Dockerfile
# Out:
# FROM tbutzer/harmony-base-python
#
# RUN mkdir -p /home/price \
#     && mkdir -p /home/price/data
#
# COPY code /home/price
#
# WORKDIR /home/price
#
# CMD ls

# %%
! make build
# Out:
# make[1]: Entering directory '/opt/harmony/class/01-docker-container-class/app-aws-price'
# docker build -t tbutzer/aws-price .
# free(): invalid pointer
# SIGABRT: abort
# PC=0x7f90182cdfb7 m=0 sigcode=18446744073709551610
# signal arrived during cgo execution
#
# goroutine 1 [syscall, locked to thread]:
# runtime.cgocall(0x4afd50, 0xc42004fcc0, 0xc42004fce8)
# 	/usr/lib/go-1.8/src/runtime/cgocall.go:131 +0xe2 fp=0xc42004fc90 sp=0xc42004fc50
# github.com/docker/docker-credential-helpers/secretservice._Cfunc_free(0x171f270)
# 	github.com/docker/docker-credential-helpers/secretservice/_obj/_cgo_gotypes.go:111 +0x41 fp=0xc42004fcc0 sp=0xc42004fc90
# github.com/docker/docker-credential-helpers/secretservice.Secretservice.List.func5(0x171f270)
# ...

# %%
! docker image ls
# Out:
# REPOSITORY                    TAG                 IMAGE ID            CREATED             SIZE
# tbutzer/aws-price             latest              b8c0d6004368        2 minutes ago       1.93GB
# <none>                        <none>              b9c9ca8c7f7f        2 minutes ago       1.93GB
# <none>                        <none>              75753a57c88a        6 minutes ago       1.93GB
# <none>                        <none>              94a5b2a0205e        14 minutes ago      1.93GB
# tbutzer/harmony-base-python   latest              2ed7dc5d4b76        25 minutes ago      1.93GB
# python                        latest              e32be9a6f71f        4 days ago          885MB

# %%
! docker image ls tbutzer/aws-price
# Out:
# REPOSITORY          TAG                 IMAGE ID            CREATED             SIZE
# tbutzer/aws-price   latest              b8c0d6004368        2 minutes ago       1.93GB

# %%
! docker run -it --rm tbutzer/aws-price python awsprice.py
# Out:
# butzer-sship-0
# 10.12.68.246
# t3a.2xlarge
# butzer-geoengine-v1
# 10.12.4.89
# t2.micro
# butzer@contractor.usgs.gov
# 10.12.69.188
# t3a.2xlarge
# butzer-bigsship-0
# 10.12.69.45
# m5a.4xlarge
